# %%
# %%bash
#
# cd /project/chihway/junzhou
#
# source "$(./miniconda3/bin/conda info --base)/etc/profile.d/conda.sh"
#
# conda activate cocoa
#
# cd ./Code-comparison/cocoa/Cocoa
#
# source ./start_cocoa.sh
#
# export OMP_NUM_THREADS=12; export OMP_PROC_BIND=close; export OMP_PLACES=cores; export OMP_DYNAMIC=FALSE
#
# mpirun -n 1 --oversubscribe --mca pml ^ucx --mca btl vader,tcp,self \
#    --bind-to core:overload-allowed --mca mpi_yield_when_idle 1 --report-bindings  \
#    --rank-by slot --map-by numa:pe=${OMP_NUM_THREADS} \
#     cobaya-run ./projects/lsst_fourier/lsst_setup0_evaluate.yaml -f
# Out:
# [midway3-0223.rcc.local:359032] Rank 0 bound to package[0][core:12-23]
# [output] Output to be read-from/written-into folder './projects/lsst_fourier/chains/lsst_setup0_evaluate', with prefix ''
# [output] Found existing info files with the requested output prefix: './projects/lsst_fourier/chains/lsst_setup0_evaluate/'
# [output] Will delete previous products ('force' was requested).
# [camb] `camb` module loaded successfully from /project/chihway/junzhou/Code-comparison/cocoa/Cocoa/external_modules/code/CAMB/camb
# [lsst_fourier.combo_3x2pt]  implement_bin_average = 1
# [lsst_fourier.combo_3x2pt]  adopt_nolimber_gg = 1
# [lsst_fourier.combo_3x2pt]  lmax_nolimber = 150
# [lsst_fourier.combo_3x2pt]  adopt_RSD_gg = 1
# [lsst_fourier.combo_3x2pt]  adopt_RSD_gs = 1
# [lsst_fourier.combo_3x2pt]  NCell_interpolation = 300
# [lsst_fourier.combo_3x2pt]  Na_interpolation = 225
# [lsst_fourier.combo_3x2pt] use_baryon_pca = False
# [evaluate] Initialized!
# [evaluate] Looking for a reference point with non-zero prior.
# [evaluate] Reference point:
#    As_1e9 = 2.1
#    ns = 0.96605
#    H0 = 67.32
#    omegab = 0.0495
#    omegam = 0.316
#    mnu = 0.06
#    w0pwa = -1
#    w = -1
#    LSST_DZ_S1 = 0
#    LSST_DZ_S2 = 0
#    LSST_DZ_S3 = 0
#    LSST_DZ_S4 = 0
#    LSST_DZ_S5 = 0
#    LSST_M1 = 0
#    LSST_M2 = 0
#    LSST_M3 = 0
#    LSST_M4 = 0
#    LSST_M5 = 0
#    LSST_A1_1 = 0.5
#    LSST_A1_2 = 0
#    LSST_DZ_L1 = 0
#    LSST_DZ_L2 = 0
#    LSST_DZ_L3 = 0
#    LSST_DZ_L4 = 0
#    LSST_DZ_L5 = 0
#    LSST_DZ_L6 = 0
#    LSST_DZ_L7 = 0
#    LSST_DZ_L8 = 0
#    LSST_DZ_L9 = 0
#    LSST_DZ_L10 = 0
#    LSST_B1_1 = 1.09
#    LSST_B1_2 = 1.15
#    LSST_B1_3 = 1.21
#    LSST_B1_4 = 1.27
#    LSST_B1_5 = 1.33
#    LSST_B1_6 = 1.4
#    LSST_B1_7 = 1.46
#    LSST_B1_8 = 1.53
#    LSST_B1_9 = 1.6
#    LSST_B1_10 = 1.67
# [evaluate] Evaluating prior and likelihoods...
# [evaluate] log-posterior  = -651.504
# [evaluate] log-prior      = 98.494
# [evaluate]    logprior_0 = 98.494
# [evaluate] log-likelihood = -749.999
# [evaluate]    chi2_lsst_fourier.combo_3x2pt = 1500
# [evaluate] Derived params:
# [evaluate]    As = 2.1e-09
# [evaluate]    wa = 0
# [evaluate]    omegabh2 = 0.0224333
# [evaluate]    omegach2 = 0.120132
# [evaluate]    omegal = 0.683921
# [evaluate]    omegamh2 = 0.143211
# [evaluate]    sigma8 = 0.811643
# [evaluate]    s8h5 = 0.98922
# [evaluate]    s8omegamp5 = 0.456256
# [evaluate]    s8omegamp25 = 0.608537
# [evaluate]    age = 13.7951
# [evaluate]    rdrag = 146.996
# [evaluate]    yheused = 0.245883
# [evaluate]    omegan2 = 0.000644867
# [evaluate]    omegan = 0.00142292
# [lsst_fourier.combo_3x2pt] Average evaluation time for lsst_fourier.combo_3x2pt: 1.58337 s  (1 evaluations)
# [camb.transfers] Average evaluation time for camb.transfers: 0.50091 s  (1 evaluations)
# [camb] Average evaluation time for camb: 0.503612 s  (1 evaluations)
